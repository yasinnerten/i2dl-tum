# %% [markdown]
# # CIFAR-10: Image Dataset
#
# Throughout this course, we will teach you all basic skills and how to use all neccessary tools that you need to implement deep neural networks, which is the main focus of this class. However, you should also be proficient with handling data and know how to prepare it for your specific task. In fact, most of the jobs that involve deep learning in industry are very data related, so this is an important skill that you have to pick up.
#
# Therefore, we will take a deep dive into data preparation this week by implementing our own datasets and dataloader. In this notebook, we will focus on the image dataset CIFAR-10. The CIFAR-10 dataset consists of 50000x3x32x32  colour (RGB) images: 50,000 images, 3 channels (RGB), and 32x32 pixels. Those images are clustered into 10 classes: *plane*, *car*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*.

# %% [markdown]
# ## (Optional) Mount in Google Colab
# Uncomment the following cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# We presume you have created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: Terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_03) is given.
# NOTE 3: To use, remove the triple " from the beginning and end of this cell.


from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_03'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
# Out:
# Mounted at /content/gdrive
# ['1_cifar10-image-dataset.ipynb', '2_dataloader.ipynb', 'exercise_code', 'images', 'models']

# %% [markdown]
# # (Optional) Colab: Revert to older runtime version
#
# As stated in exercise 1, Google Colab moved to Python 3.12 in August 2025. This may cause compatibility issues with some of the course's exercises. Therefore, if running them in colab, revert to the runtime version of July 2025. To do this, go to Runtime >> Change runtime type >> Runtime version.
#
# <img name="revert runtime" src="https://i2dl.vc.in.tum.de/static/images/exercise_01/runtime_change.png" width="400">

# %% [markdown]
# ## Imports

# %% [markdown]
# Let's start by importing some libraries that you will need along the way, as well as some code files that you will work on throughout this notebook.

# %%
import os
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

from exercise_code.data import (
    ImageFolderDataset,
)
from exercise_code.tests import (
    test_rescale_transform,
    test_compute_image_mean_and_std,
    test_len_dataset,
    test_item_dataset,
    test_transform_dataset,
    test_normalization_transform,
    save_pickle
)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
os.environ['KMP_DUPLICATE_LIB_OK']='True' # To prevent the kernel from dying.

# %% [markdown]
# ## 1. Dataset Download
# Let us get started by downloading the data. In `exercise_code/data/image_folder_dataset.py` you can find a class `ImageFolderDataset`, which you will have to complete throughout this notebook.
#
# This class automatically downloads the raw data for you. To do so, simply initialize the class as below.
#
# **Note** Downloading and zipping the dataset might take a while, ESPECIALLY if you are using Google Colab. So be patient!

# %%
# If working with colab uncomment the following line:

### colab only ###
import urllib.request
### colab only ###

# %%
# Set up the output dataset folder
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(i2dl_exercises_path, "datasets", "cifar10")

# Init the dataset and display downloading information this one time
dataset = ImageFolderDataset(
    root=cifar_root,
    force_download=True,
    verbose=True
)
# Out:
# Downloading cifar10.zip
# Downloading https://i2dl.vc.in.tum.de/static/data/cifar10.zip to /content/gdrive/MyDrive/i2dl/datasets/cifar10/cifar10.zip
# 120725504it [00:07, 15999739.90it/s]
# Extracting cifar10.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-9-2561591477.py in <cell line: 0>()
#       4
#       5 # Init the dataset and display downloading information this one time
# ----> 6 dataset = ImageFolderDataset(
#       7     root=cifar_root,
#       8     force_download=True,
#
# /content/gdrive/MyDrive/i2dl/exercise_03/exercise_code/data/image_folder_dataset.py in __init__(self, transform, download_url, *args, **kwargs)
#      21                  download_url="https://i2dl.vc.in.tum.de/static/data/cifar10.zip",
#      22                  **kwargs):
# ---> 23         super().__init__(*args,
#      24                          download_url=download_url,
#      25                          **kwargs)
#
# /content/gdrive/MyDrive/i2dl/exercise_03/exercise_code/data/base_dataset.py in __init__(self, root, download_url, force_download, verbose)
#      18             dataset_zip_name = download_url[download_url.rfind('/')+1:]
#      19             self.dataset_zip_name = dataset_zip_name
# ---> 20             download_dataset(
#      21                 url=download_url,
#      22                 data_dir=root,
#
# /content/gdrive/MyDrive/i2dl/exercise_03/exercise_code/data/download_utils.py in download_dataset(url, data_dir, dataset_zip_name, force_download, verbose)
#     128         if verbose:
#     129             print('Extracting', dataset_zip_name)
# --> 130         extract_archive(data_file, remove_finished=True)
#     131         if verbose:
#     132             print('Dataset successfully downloaded! Stored under:', data_dir)
#
# /content/gdrive/MyDrive/i2dl/exercise_03/exercise_code/data/download_utils.py in extract_archive(from_path, to_path, remove_finished)
#     101     elif _is_zip(from_path):
#     102         with zipfile.ZipFile(from_path, 'r') as zip_:
# --> 103             zip_.extractall(to_path)
#     104     else:
#     105         raise ValueError("Extraction of {} not supported".format(from_path))
#
# /usr/lib/python3.11/zipfile.py in extractall(self, path, members, pwd)
#    1700
#    1701         for zipinfo in members:
# -> 1702             self._extract_member(zipinfo, path, pwd)
#    1703
#    1704     @classmethod
#
# /usr/lib/python3.11/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1754
#    1755         with self.open(member, pwd=pwd) as source, \
# -> 1756              open(targetpath, "wb") as target:
#    1757             shutil.copyfileobj(source, target)
#    1758
#
# KeyboardInterrupt:

# %% [markdown]
# You should now be able to see the images in `i2dl_exercises/datasets/cifar10` in your file browser, which should contain one subfolder per class, each containing the respective images labeled `0001.png`, `0002.png`, ...

# %% [markdown]
# By default, the dataset will only be downloaded the first time you initialize a dataset class. If, for some reason, your version of the dataset gets corrupted and you wish to re-download it, simply initialize the class with `force_download=True` in the download cell above.

# %% [markdown]
# **Important notice for colab:**
#
# By running the above cell, the dataset is mounted to the runtime you are currently using. But it takes time to save the dataset to your google drive. The dataset might not be complete saved on your google drive due to many reason. When you restart the runtime or try to access cifar10 from another notebook, you may got error. When this happens, run the following cell in colab to redownload and extract the dataset for the runtime.

# %%
### Only when you got error regarding cifar10 in colab ###
# !mkdir -p /content/gdrive/MyDrive/i2dl/datasets/cifar10
# !wget -P /content/gdrive/MyDrive/i2dl/datasets/cifar10/ https://i2dl.vc.in.tum.de/static/data/cifar10.zip
# !unzip -o /content/gdrive/MyDrive/i2dl/datasets/cifar10/cifar10.zip -d /content/gdrive/MyDrive/i2dl/datasets/cifar10
# !rm -f /content/gdrive/MyDrive/i2dl/datasets/cifar10/cifar10.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/2018.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/0521.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/0837.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/1292.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/1169.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/4410.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/ship/2770.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2952.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2812.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4967.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0455.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2983.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0473.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0892.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2713.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0859.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3924.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2199.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1716.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2467.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0640.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1035.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4558.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2737.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0276.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3515.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0525.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0025.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1943.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2197.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3143.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3861.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0487.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1449.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3454.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0952.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2839.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1477.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2042.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2362.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3626.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0669.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2080.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4062.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1561.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2614.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0357.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1209.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4388.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1418.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1831.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2820.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3394.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3932.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1694.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0531.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1384.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1431.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0985.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3667.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0724.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2344.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1805.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1768.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0302.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3685.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2102.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3371.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4701.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4826.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1867.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4294.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2483.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1450.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3808.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2861.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0443.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3566.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0554.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4537.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0717.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3261.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4421.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3294.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0054.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1033.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2203.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4208.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2500.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3068.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1668.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4888.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3528.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0588.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0817.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4315.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0072.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4397.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4223.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0287.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2854.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3203.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4298.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4991.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4190.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4518.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2735.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4721.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3081.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0002.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3929.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4018.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0834.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1745.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0370.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3697.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2219.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2576.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3692.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0789.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4002.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2843.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1006.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3998.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3585.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1760.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3550.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4077.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3509.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0520.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0202.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1756.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4215.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0484.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4285.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3446.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0436.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4331.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4934.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3078.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4669.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0825.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4946.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2651.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0743.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3100.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0359.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4739.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2030.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0282.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3828.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0884.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0782.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3282.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1717.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1751.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2280.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4423.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2493.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3431.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2696.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3213.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1025.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0656.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1598.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3877.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4301.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2251.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4780.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0734.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4342.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1693.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3494.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3441.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3004.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3539.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4367.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0514.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2058.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0015.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1340.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0411.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1219.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3987.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0936.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4969.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0474.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4515.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1934.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3897.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0303.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3382.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1358.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0596.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3072.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2057.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3380.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4573.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0467.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2709.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2986.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4812.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4704.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2271.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0386.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1544.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3569.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3251.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0207.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3604.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2152.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2828.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3660.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1786.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3249.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2616.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1578.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0061.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4667.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3573.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3348.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0622.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2849.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0585.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1656.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1812.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2853.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2721.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0579.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1767.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1592.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0922.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2569.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2988.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1699.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1515.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3543.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4949.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3839.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1455.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1572.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3552.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0577.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4955.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4255.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3387.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1815.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0149.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3296.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4769.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0679.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1269.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3520.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1602.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2260.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4819.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1423.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4204.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1254.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4868.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0014.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1871.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0813.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4408.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2486.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2931.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3735.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3416.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1162.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1420.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2981.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1365.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1046.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4052.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3172.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4950.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4445.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2029.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0087.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2326.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4500.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1956.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3916.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2119.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2556.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2182.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3755.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1380.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1822.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1820.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3785.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0949.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0879.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2631.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2596.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4005.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1949.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3198.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3217.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4093.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1854.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2933.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3041.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3307.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2902.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1841.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3980.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1089.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3020.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1882.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2051.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1903.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0465.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2329.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0458.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0101.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4427.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0400.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0762.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3599.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0384.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3083.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4477.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4924.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1053.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4155.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3679.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1337.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2540.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0891.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0033.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2802.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4479.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2732.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2716.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2499.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0989.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1735.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3305.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0214.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0750.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2775.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0122.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3818.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3044.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4738.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1742.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4400.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4502.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2322.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1429.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4616.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3174.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4015.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4936.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2112.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4953.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0546.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1838.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4621.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2722.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4361.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3977.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0100.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2589.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3504.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1631.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1541.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0026.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4429.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2512.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0639.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0716.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0410.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4983.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1085.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4528.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0251.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4493.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2003.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2840.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2439.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2921.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1171.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2126.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0614.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4831.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4816.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2549.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0321.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1991.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3651.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3074.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3201.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0906.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3477.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3239.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3131.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4201.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3796.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4304.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0185.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2321.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2846.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3628.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4505.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2246.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4127.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3397.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4364.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1788.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0171.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1061.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4043.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1075.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0998.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1304.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1245.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3901.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4091.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4904.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4444.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4843.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0007.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0610.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4363.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4123.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2115.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2550.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3491.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2278.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3046.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2883.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1781.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2649.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0575.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1193.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3098.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3450.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3005.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1012.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0990.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3952.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1220.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1366.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1348.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0513.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0032.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2792.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1461.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1859.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1928.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4438.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0398.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2502.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2661.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2337.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2282.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3246.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4322.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2019.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2137.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2164.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1612.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2270.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3421.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2857.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4932.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2067.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3703.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4940.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4160.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1968.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0106.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4399.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2290.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0721.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0416.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0944.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3436.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1599.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1016.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0864.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4371.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1496.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4349.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0311.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0396.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1475.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1277.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4019.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3521.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0403.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2485.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0394.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2461.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2868.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3759.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4170.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1100.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1196.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2106.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1721.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2370.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3240.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2869.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1343.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3738.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3503.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1752.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4697.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0890.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4108.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0305.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0573.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2860.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4271.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0686.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4597.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2352.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1700.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1808.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3643.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2751.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0069.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1555.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4626.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3401.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1440.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2261.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0862.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2273.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1652.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1207.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4922.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3189.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0340.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0954.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2959.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4724.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1134.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4152.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0682.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3492.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2525.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4687.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1937.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1914.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3671.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3740.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3603.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3176.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3935.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4679.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0335.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2498.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2581.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0446.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4007.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1067.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0453.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1795.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3805.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1480.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3018.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0611.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0725.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4980.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0732.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2827.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2704.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2245.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4951.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2063.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3187.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3668.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1846.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3433.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4348.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4938.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1902.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2023.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3456.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1202.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2919.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4989.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1244.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2783.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1829.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2731.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3955.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2686.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2267.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4975.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2572.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1208.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0181.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1792.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2259.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1568.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0978.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1295.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3826.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4632.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4542.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1482.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1395.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2922.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2150.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1804.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3377.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2412.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3458.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4417.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3024.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4594.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0569.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0773.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0517.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1789.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0131.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0654.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2947.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0972.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3323.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2930.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2935.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4850.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0957.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3648.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2705.png
# ...
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1743.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4766.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0030.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1299.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2096.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4210.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3367.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2382.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1007.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1060.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4860.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1671.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3706.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0661.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4611.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0241.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4754.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4582.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1127.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4411.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2916.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4120.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1493.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3398.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1651.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1942.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3353.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3374.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4703.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1293.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1661.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0166.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0155.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1478.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4577.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3835.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4740.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3408.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2845.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3993.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0324.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3639.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3424.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3551.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1279.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4448.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1712.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4128.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1027.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2640.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4365.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3443.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1329.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0543.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4175.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2760.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0313.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4553.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4719.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4617.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0931.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1663.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1593.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1445.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1501.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4089.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2618.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2487.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3732.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3163.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2657.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0697.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2482.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2698.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4710.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3067.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4267.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3470.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2151.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3003.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4344.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0199.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2367.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1194.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4105.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1291.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2142.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2252.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4648.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4886.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3583.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4447.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1898.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2948.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0562.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1076.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4251.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1997.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0238.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1746.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1966.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3465.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3588.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1258.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2555.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1625.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2430.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3484.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2191.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4187.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0847.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4372.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2046.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4735.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3592.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4909.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4368.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0672.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0326.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4136.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2141.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0130.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3787.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3102.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0960.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2814.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1998.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0344.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4557.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4406.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1720.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1454.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3467.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0769.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1044.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3967.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4124.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0227.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0019.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4836.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1799.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0211.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2103.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2470.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2053.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0605.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0243.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0816.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1345.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0548.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2044.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0304.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3931.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1317.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3545.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2749.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3110.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2269.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3128.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4507.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3974.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0877.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0841.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0024.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3350.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4168.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1098.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1659.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1830.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1793.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0959.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2836.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2725.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0074.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3862.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4192.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4252.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3630.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1050.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2010.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1381.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2166.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4078.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2026.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1558.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2120.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0039.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1338.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3344.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1692.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3711.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4877.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0848.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4931.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1917.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0426.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4076.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4264.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4717.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1876.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/3178.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1013.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4404.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2018.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0521.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/0837.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1292.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/1169.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/4410.png
#  extracting: /content/gdrive/MyDrive/i2dl/datasets/cifar10/truck/2770.png

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# Before training any model you should *always* take a look at some samples of your dataset. In this way, you can make sure that the data input has worked as intended and also get a feeling for the dataset.
#
# Let's load the CIFAR-10 data and visualize a subset of the images. To do so, `PIL.Image.open()` is used to open an image, and then `numpy.asarray()` to cast the image to a numpy array, which will have shape 32x32x3 (Note that it is different from the default shape format used in this course, CxHxW). In this way 7 images will be loaded per class, and then use `matplotlib.pyplot` to visualize those images in a grid.

# %%
def load_image_as_numpy(image_path):
    return np.asarray(Image.open(image_path), dtype=float)

classes = [
    'plane', 'car', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck',
]
num_classes = len(classes)
samples_per_class = 7
for label, cls in enumerate(sorted(classes)):
    for i in range(samples_per_class):
        image_path = os.path.join(
            cifar_root,
            cls,
            str(i+10).zfill(4) + ".png"
        )  # e.g. cifar10/plane/0001.png
        image = np.asarray(Image.open(image_path))  # open image as numpy array
        plt_idx = i * num_classes + label + 1  # calculate plot location in the grid
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(image.astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)  # plot class names above columns
plt.show()

# %% [markdown]
# ## 3. ImageFolderDataset Implementation
#
# Loading images by following the code above is a bit cumbersome. Therefore, the next step is to write a custom **Dataset** class, which takes care of the data loading. This is always the first thing you have to implement when starting a new deep learning project.

# %% [markdown]
# ### 3.1 Dataset Class
#
# The **Dataset** class is a wrapper that loads the data from a given file path and returns a python dictionary containing the prepared data, as you have done above. Datasets always need to have the following two methods implemented:
# - `__len__(self)` is a method that should simply calculate and return the number of images in the dataset. After it is implemented, you can simply call it with `len(dataset)`.
# - `__getitem__(self, index)` should return the image with the given index from your dataset. Implementing this will allow you to access your dataset like a list, i.e. you can then simply call `dataset[9]` to access the 10th image in the dataset.
#
# Generally, you will have to implement a different dataset for every project. However, base dataset classes for future projects will be provided for you in future projects.

# %% [markdown]
# ### 3.2 ImageFolderDataset Implementation
#
# Now it is your turn to implement such a dataset class for CIFAR-10. To do so, open `exercise_code/data/image_folder_dataset.py` and check the following three methods of `ImageFolderDataset`:
# - `make_dataset(directory, class_to_idx)` should load the prepared data from a given directory root (`directory`) into two lists (`images` and `labels`). `class_to_idx` is a dict mapping class (e.g. 'cat') to label (e.g. 1). **Note**: This function is called in the `__init__` method of the dataset class only ONCE, and is not intended to be called by the user again.
# - `__len__(self)` should calculate and return the number of images in your dataset.
# - `__getitem__(self, index)` should return the image with the given index from your dataset.

# %% [markdown]
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please read <code>make_dataset(directory, class_to_idx)</code> and make sure to familiarize with its output as you will need to interact with it for the following tasks. Additionally, it would be a wise decision to get familiar with python's os library which will be of utmost importance for most datasets you will write in future projects. As it is not beginner friendly, we removed it for this exercise but it is an important skill for a DL practicer.</p>
# </div>
#
# **Note**: This function is called in the `__init__` method of the dataset class only ONCE, and is not intended to be called by the user again.

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>__len__(self)</code> method in <code>exercise_code/data/image_folder_dataset.py</code> and test your implementation by running the following cell.
#     </p>
# </div>

# %%
from exercise_code.data.image_folder_dataset import ImageFolderDataset

dataset = ImageFolderDataset(
    root=cifar_root,
)
_ = test_len_dataset(dataset)
# Out:
# ####### Testing Started #######
#
# Test LenTestInt: passed!
# Test LenTestCorrect: passed!
#
# ####### Testing Finished #######
# Method __len__(): passed! -->  Tests passed: 2/2
# Score: 100/100

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>__getitem__(self, index)</code> method in <code>exercise_code/data/image_folder_dataset.py</code> and test your implementation by running the following cell.
#     </p>
#     <p><b>Hint:</b> You may want to reuse parts of the '2. Data Visualization' code above in your implementation of <code>__getitem__()</code>.
# </div>

# %%
from exercise_code.data.image_folder_dataset import ImageFolderDataset

dataset = ImageFolderDataset(
    root=cifar_root,
)

_ = test_item_dataset(dataset)
# Out:
# ####### Testing Started #######
#
# Test GetItemTestType: passed!
# Test GetItemTestImageShape: passed!
#
# ####### Testing Finished #######
# Method __getitem__(): passed! -->  Tests passed: 2/2
# Score: 100/100

# %% [markdown]
# ### 3.3 Dataset Usage
#
# Now that you have implemented all the required parts of the ImageFolderDataset, using the `__getitem__()` method, you can now access our dataset as conveniently as you would access a list:

# %%
sample_item = dataset[0]
sample_image = sample_item["image"]
sample_label = sample_item["label"]

print('Sample image shape:', sample_image.shape)
print('Sample label:', sample_label)
print('Sample image first values:', sample_image[0][0])
# Out:
# Sample image shape: (32, 32, 3)
# Sample label: 0
# Sample image first values: [  3. 125. 233.]

# %% [markdown]
# As you can see, the images are represented as uint8 values for each of the three RGB color channels. The data type and scale are fundamental in computer vision. `uint8` stands for **unsigned integer 8-bit**. It is a data type that can represent integer values in the range of 0 to 255 RGB values are typically represented as uint8 because it can represent 256 shades of a color, which is sufficient for most applications. Each color component plane can have a range of values from 0 to 255.
#
# As you have implemented both `__len__()` and `__getitem__()`, you can now even iterate over the dataset with a simple for loop!
#
# **Note**: If it takes too long, just skip this cell. The purpose of the cell is only to show you that your dataset is iterable.

# %%
num_samples = 0
max_num_samples = 100

for i, sample in enumerate(tqdm(dataset, total=max_num_samples)):
    if i >= max_num_samples:
        break
    num_samples += 1

print("Number of samples:", num_samples)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 160.31it/s]
# Number of samples: 100

# %% [markdown]
# ### 3.4 The crux of loading from disk
# If you are using google colab or store your files on a local HDD, executing the above cell takes quite some time. This is problematic, since we want to iterate over the dataset in future exercises. The issue is that we access single files every time we access a dataset element, which are then loaded into the memory.
#
# Luckily, the CIFAR10 dataset is small enough to fit into the memory for most systems, since it's total file size is around 1.2GB.
#
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>Loading the whole dataset into memory will not work if you are using a machine with 4GB of RAM or less (depending on your other programs such as memory hungry web browsers). Consider closing some open programs or simply use the local on-demand ImageFolderDataset.</p>
#     <p>In addition we want to warn you that everytime you execute a cell like "dataset2 = MemoryImageFolderDataset..." you are loading a 1.2GB matrix into your memory. If you do this often enough this notebook will crash on every machine. Therefore, we make sure to always use a single variable "dataset" which will be overwritten by future cells to avoid straining your memory too much.</p>
# </div>
#
# We created a second CIFAR10 dataset for you where we load all images into the memory instantly instead of loading them on demand at access time, which speeds up the loading speed immensly, especially on google colab. You can check out the code under `exercise_coder/data/image_folder_dataset`.

# %%
# Don't execute this cell on low RAM machines
from exercise_code.data import MemoryImageFolderDataset
### colab only ###
import urllib.request
### colab only ###

dataset = MemoryImageFolderDataset(
    root=cifar_root,
    force_download=True,
    verbose=True
)
# Out:
# Downloading cifar10memory.zip
# Downloading https://i2dl.vc.in.tum.de/static/data/cifar10memory.zip to /content/gdrive/MyDrive/i2dl/datasets/cifar10memory/cifar10memory.zip
# 207708160it [01:11, 2911321.14it/s]
# Extracting cifar10memory.zip
# Dataset successfully downloaded! Stored under: /content/gdrive/MyDrive/i2dl/datasets/cifar10memory

# %% [markdown]
# We can now easily iterate over the whole dataset, once it is loaded into our memory, which should be way faster than the previous iteration.
#
# **Note**: If it takes too long, just skip this cell. The purpose of the cell is only to show you that your dataset is iterable.

# %%
num_samples = 0
max_num_samples = 100

for i, sample in enumerate(tqdm(dataset, total=max_num_samples)):
    if i >= max_num_samples:
        break
    num_samples += 1

print("Number of samples:", num_samples)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 463971.68it/s]
# Number of samples: 100

# %% [markdown]
# ### 3.5 Choose your preferred dataset here
# If you want to switch to the ImageFolderDataset for the remaining notebook, please change the following cell. The default is MemoryImageFolderDataset for efficiency reasons.

# %%
# DATASET = ImageFolderDataset
DATASET = MemoryImageFolderDataset

# %% [markdown]
# ## 4. Transforms and Image Preprocessing
#
# Before training machine learning models, you often need to pre-process the data. For image datasets, two commonly applied techniques are:
# 1. Normalize all images so that each value is either in [-1, 1] or [0, 1]. By doing so the image are also converted to floating point numbers.
# 2. Compute the mean over all images and subtract this mean from all images in the dataset
#
# These transform classes are callables, meaning that you will be able to simply use them as follows:
#
# ```transform = Transform()```
#
# ```images_transformed = transform(images)```
#
# This will be realized in the pipeline by defining so called transforms. Instead of applying them globally to the input data, you will apply those seperatly to each sample after loading it in the `__getitem__` call of the dataset.
#
# However, note that you don't need to create any of them yourselvs, as we're doing that for you.

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Modify the <code>__getitem__(self, index)</code> method in <code>exercise_code/data/image_folder_dataset.py</code> such that it applies <code>self.transform</code>, if applicablie - if such a transform function was sent as an argument. With this change you can simply define the transforms during dataset creation and apply those automatically for each <code>__getitem__</code> call. Make sure not to break it though ;).
# </div>

# %%
dataset = DATASET(
    root=cifar_root,
)

_ = test_transform_dataset(dataset)
# Out:
# ####### Testing Started #######
#
# Test GetItemTestType: passed!
# Test GetItemTestImageShape: passed!
# Test GetItemTestTransformApplied: passed!
#
# ####### Testing Finished #######
# Method __getitem__(): passed! -->  Tests passed: 3/3
# Score: 100/100

# %% [markdown]
# Equipped with this change, you can now easily add the two preprocessing techniques above for CIFAR-10. You will do so in the following steps by implementing the classes `RescaleTransform` and `NormalizeTransform` in `exercise_code/data/transforms.py`.

# %% [markdown]
# ### 4.1 Rescaling Images using RescaleTransform
#
# Let's start by implementing `RescaleTransform`. If you look at the `__init__()` method, you will notice it has four arguments:
# * **out_range** is the range you wish to rescale your images to. E.g. if you want to scale your images to [-1, 1], you would use `range=(-1, 1)`. By default, they will be scaled to [0, 1].
# * **in_range** is the value range of the data prior to rescaling. For uint8 images, this will always be (0, 255).

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>__call__()</code> method of <code>RescaleTransform</code> in <code>exercise_code/data/transforms.py</code> and test your implementation by running the following cell.
# </div>

# %%
from exercise_code.data.transforms import RescaleTransform

rescale_transform = RescaleTransform()
dataset_rescaled = DATASET(
    root=cifar_root,
    transform=rescale_transform
)

orig_dataset = DATASET(root=cifar_root)
_ = test_rescale_transform(orig_dataset, dataset_rescaled)
# Out:
# ####### Testing Started #######
#
# Test RescaleTransformUnitTest: passed!
#
# ####### Testing Finished #######
# Class RescaleTransform: passed! -->  Tests passed: 1/1
# Score: 100/100

# %% [markdown]
# If you look at the first image, you should now see that all values are between 0 and 1.

# %%
sample_item = dataset_rescaled[0]
sample_label = sample_item["label"]
sample_image = sample_item["image"]

print("Max value:", np.max(sample_image))
print("Min value:", np.min(sample_image))
print('Sample rescaled image first values:', sample_image[0][0])
# Out:
# Max value: 1.0
# Min value: 0.00392156862745098
# Sample rescaled image first values: [0.01176471 0.49019608 0.91372549]

# %% [markdown]
# ### 4.2 Normalize Images to Standard Gaussian using NormalizeTransform
#
# Let us now move on to the `NormalizeTransform` class. The `NormalizeTransform` class normalizes images channel-wise and its `__init__` method has two arguments:
# * **mean** is the normalization mean, which will be subtracted from the dataset.
# * **std** is the normalization standard deviation. By scaling the data with a factor of `1/std` the standard deviation will be normazlied accordingly.
#
# Have a look at the code in `exercise_code/data/transforms.py`.
#
# The next step is to normalize the CIFAR-10 **images channel-wise** to standard normal. To do so, you need to calculate the **per-channel image mean and standard deviation** first, which you can then provide to `NormalizeTransform` to normalize the data accordingly.
#
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>The next step loads the whole CIFAR10 dataset into your memory so we can work in it. If the notebook crashes it is most likely because you are running out of memory since the following step allocates 1.2GB of memory footprint. If that is an issue for your system, consider not using the MemoryImageFolderDataset or switch to google colab.</p>
# </div>

# %%
# You first have to load all rescaled images
rescaled_images = []
for sample in tqdm(dataset_rescaled, position=0, leave=True):
    rescaled_images.append(sample["image"])
rescaled_images = np.array(rescaled_images)
# Out:
# 100%|██████████| 50000/50000 [00:01<00:00, 26451.57it/s]

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>compute_image_mean_and_std()</code> method and the <code>__call__()</code> method of <code>NormalizeTransform</code> in <code>exercise_code/data/transforms.py</code>. Compute the rescaled dataset's mean and variance by running the following cell.
# </div>

# %%
from exercise_code.data.transforms import compute_image_mean_and_std

cifar_mean, cifar_std = compute_image_mean_and_std(rescaled_images)
print("Mean:\t", cifar_mean, "\nStd:\t", cifar_std)
# Out:
# Mean:	 [0.49191375 0.48235852 0.44673872]
# Std:	 [0.24706447 0.24346213 0.26147554]

# %% [markdown]
# To test your implementation, run the following code:

# %%
_ = test_compute_image_mean_and_std(cifar_mean, cifar_std)
# Out:
# ####### Testing Started #######
#
# Test CIFARImageStatisticTest (mean): passed!
# Test CIFARImageStatisticTest (std): passed!
#
# ####### Testing Finished #######
# Method compute_image_mean_and_std(): passed! -->  Tests passed: 2/2
# Score: 100/100

# %%
# The rescaled images will be deleted now from your ram as they are no longer needed
try:
    del rescaled_images
except NameError:
    pass

# %% [markdown]
# Now you can use the mean and standard deviation you computed to normalize the loaded data. This can be done by simply adding the `NormalizeTransform` to the list of transformations our dataset applies in `__getitem__()`.

# %% [markdown]
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check out the <code>ComposeTransform</code> in <code>transforms.py</code>. Later on, we will most often use multiple transforms and chain them together. Remember that the order is of importance here!</p>
# </div>

# %%
from exercise_code.data.image_folder_dataset import ImageFolderDataset
from exercise_code.data.transforms import RescaleTransform, NormalizeTransform, ComposeTransform

# Set up both transforms using the parameters computed above
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)

dataset = ImageFolderDataset(
    root=cifar_root,
    transform=ComposeTransform([rescale_transform, normalize_transform])
)

# %% [markdown]
# Test your code: Run the following cell to see if your normalization worked.

# %%
# Don't change the values of these variables - the test validates only this specific pixel.

orig_data = ImageFolderDataset(root=cifar_root)
_ = test_normalization_transform(orig_data, dataset, cifar_mean, cifar_std)
# Out:
# ####### Testing Started #######
#
# Test NormalizationTest: passed!
#
# ####### Testing Finished #######
# Method NormalizationTransform(): passed! -->  Tests passed: 1/1
# Score: 100/100

# %% [markdown]
# You can now check out the results of the transformed samples:

# %%
sample_item = dataset[0]
sample_label = sample_item["label"]
sample_image = sample_item["image"]

print('Sample normalized image shape:', sample_image.shape)
print('Sample normalized image first values:', sample_image[0][0])
# Out:
# Sample normalized image shape: (32, 32, 3)
# Sample normalized image first values: [-1.94341602  0.03219212  1.7859673 ]

# %% [markdown]
# ## 5. Save your Dataset
# Now save your dataset and transforms using the following cell. This will save it to a pickle file `models/cifar_dataset.p`. We will use this dataset for the next notebook and this will count for the submission.

# %% [markdown]
# <div class="alert alert-danger">
#     <h3>Note</h3>
#     <p>Each time you make changes in `dataset`, you need to rerun the following code to make your changes saved, but <b>this is NOT the file which you should submit</b>. You will find the final file for submission in the second notebook.</p>
# </div>

# %%
save_pickle(
    data_dict={
        "dataset": dataset,
        "cifar_mean": cifar_mean,
        "cifar_std": cifar_std,
    },
    file_name="cifar_dataset.p"
)

# %% [markdown]
# <div class="alert alert-danger">
#     <h3>Note</h3>
#     <p>It can take some time for the pickle file to appear on google colab. In that case, strech your limbs and brew a fresh coffee/tea/water before you continue</p>
# </div>

# %% [markdown]
# # Key Takeaways
# 1. Always have a look at your data before you start training any models on it.
# 2. Datasets should be organized in corresponding **Dataset** classes that support `__len__` and `__getitem__` methods, which allow us to call `len(dataset)` and `dataset[index]`.
# 3. Data often needs to be preprocessed. Such preprocessing can be implemented in **Transform** classes, which are callables that can be simply applied via `data_transformed = transform(data)`. However, we will rarely do that and apply transforms on the fly using a dataloader which we will introduce in the next notebook.
